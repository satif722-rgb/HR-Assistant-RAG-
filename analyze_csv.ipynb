# %%
import pandas as pd

# %%
df=pd.read_csv("similarity_logs.csv")
df.head()
# Out:
#                                                       timestamp  question  \
# 2025-12-31T15:35:50  How many earned leaves can be accumulated?         1
# 2025-12-31T15:35:50  How many earned leaves can be accumulated?         2
# 2025-12-31T15:35:50  How many earned leaves can be accumulated?         3
# 2025-12-31T15:35:50  How many earned leaves can be accumulated?         4
# 2025-12-31T15:35:50  How many earned leaves can be accumulated?         5
#
#                       score         file_name  page  \
# 2025-12-31T15:35:50  0.7323  leave_policy.pdf     0
# 2025-12-31T15:35:50  0.8207  leave_policy.pdf     0
# 2025-12-31T15:35:50  0.9518  leave_policy.pdf     1
# 2025-12-31T15:35:50  0.9987  leave_policy.pdf     0
# 2025-12-31T15:35:50  1.0014  leave_policy.pdf     0
#
#                                                           text_preview
# 2025-12-31T15:35:50   Accumulation:  o Earned Leave can be accumul...
# ...

# %%
df.tail()
# Out:
#                                      timestamp  question   score  \
# 2025-12-31T15:42:48  tell me about leave rules         1  0.6819
# 2025-12-31T15:42:48  tell me about leave rules         2  0.7434
# 2025-12-31T15:42:48  tell me about leave rules         3  0.7772
# 2025-12-31T15:42:48  tell me about leave rules         4  0.7851
# 2025-12-31T15:42:48  tell me about leave rules         5  0.7906
#
#                             file_name  page  \
# 2025-12-31T15:42:48  leave_policy.pdf     3
# 2025-12-31T15:42:48  leave_policy.pdf     3
# 2025-12-31T15:42:48  leave_policy.pdf     3
# 2025-12-31T15:42:48  leave_policy.pdf     0
# 2025-12-31T15:42:48  leave_policy.pdf     0
#
#                                                           text_preview
# 2025-12-31T15:42:48  beginning of each calendar year.    Taking Lea...
# 2025-12-31T15:42:48   Advance Communication:  o All leave and Work...
# 2025-12-31T15:42:48  the day the leave is taken.  o Communication c...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 115 entries, 2025-12-31T15:35:50 to 2025-12-31T15:42:48
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     115 non-null    object
#  1   question      115 non-null    int64
#  2   score         115 non-null    float64
#  3   file_name     115 non-null    object
#  4   page          115 non-null    int64
#  5   text_preview  115 non-null    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 6.3+ KB

# %%
print(df["score"].describe())
# Out:
# count    115.000000
# mean       0.883144
# std        0.178944
# min        0.430200
# 25%        0.776250
# 50%        0.872300
# 75%        1.000050
# max        1.223100
# Name: score, dtype: float64

# %%
best_per_question = (
    df.sort_values("score")
      .groupby("question")
      .first()
      .reset_index()
)

print(best_per_question[["question", "score", "file_name"]])
# Out:
#    question   score         file_name
# 0         1  0.4302  leave_policy.pdf
# 1         2  0.4928  leave_policy.pdf
# 2         3  0.6633  leave_policy.pdf
# 3         4  0.7534  leave_policy.pdf
# 4         5  0.7676  leave_policy.pdf
